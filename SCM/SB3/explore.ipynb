# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid", palette="deep")

# %%
transitions = pd.read_csv("./transitions_TD3_1.csv")

# %%
transitions.head()
# Out:
#    t  factory_stock  warehouse_stock_0  warehouse_stock_1  production_level  \
# 0  0       2.036174           2.214975           3.740906          9.992055
# 1  1       2.902233          -0.784649           1.969107          1.094636
# 2  2       1.745474           1.743412           0.491292          4.893488
# 3  3       3.012711           1.329769           0.456579          3.818880
# 4  4       3.043699           1.072308           0.587117          2.904066
#
#    shipping_to_warehouse_0  shipping_to_warehouse_1  timestep_reward  \
# 0                 3.214975                 4.740906      -263.166130
# 1                 0.000376                 0.228201       418.552998
# 2                 4.528061                 1.522185       170.314349
# 3                 0.586357                 1.965287       111.247786
# 4                 0.742539                 2.130539       144.735323
#
#    total_reward
# 0   -263.166130
# 1    155.386868
# 2    325.701217
# 3    436.949003
# 4    581.684326

# %%
plt.figure(figsize=(18, 5))
plt.plot(transitions["factory_stock"])
plt.plot(transitions["warehouse_stock_0"])
plt.plot(transitions["warehouse_stock_1"])

# %%
plt.figure(figsize=(18, 5))
plt.plot(transitions["production_level"])
plt.plot(transitions["shipping_to_warehouse_0"])
plt.plot(transitions["shipping_to_warehouse_1"])

# %%
plt.figure(figsize=(18, 5))
plt.plot(transitions["timestep_reward"])

# %%
plt.figure(figsize=(18, 5))
plt.plot(transitions["total_reward"])

# %%
print(f"Max Rewards: {transitions['total_reward'].iloc[-1]}")
# Out:
# Max Rewards: 7014.892011106014
